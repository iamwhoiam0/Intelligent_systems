# %% [markdown]
# ## Задание на лабораторную работу

# %% [markdown]
# Реализовать классификацию сортов растения ирис (Iris Setosa - 0, Iris Versicolour - 1, Iris
# Virginica - 2) по четырем признакам: размерам пестиков и тычинок его цветков.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# Поключаем модули

# %%
import pandas
import matplotlib.pyplot as plt 
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# Набор данных загружается с помощью библиотеки Pandas. После загрузки данных из файла ```python dataframe = pandas.read_csv("iris.csv", header=None)``` , необходимо разделить столбцы на входные данные (X) и выходные данные (Y).

# %%
dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]
##print('X=',X)
##print('----------------------------------------------')
##print('Y=',Y)

# %% [markdown]
# При решении задач многоклассовой классификации хорошей практикой является
# преобразование выходных атрибутов из вектора в матрицу к виду представленных ниже.

# %% [markdown]
# |Iris-setosa|Iris-versicolor|Iris-verginica|
# |-----------|---------------|--------------|
# |1|0|0|
# |0|1|0|
# |0|0|1|

# %% [markdown]
# Для этого необходимо использовать функцию *to_categorical()*

# %%
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
##print(dummy_y)

# %% [markdown]
# Далее надо задать базовую архитектуру сети.

# %%
model = Sequential()
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# Далее нужно подготовить сеть к обучению. Чтобы подготовить сеть к обучению, нужно настроить еще три параметра для этапа
# компиляции:
# 1. **функцию потерь**, которая определяет, как сеть должна оценивать качество своей работы на обучающих данных и, соответственно, как корректировать ее в правильном направлении;
# 2. **оптимизатор** — механизм, с помощью которого сеть будет обновлять себя, опираясь на наблюдаемые данные и функцию потерь;
# 3. **метрики для мониторинга на этапах обучения и тестирования** — здесь нас будет интересовать только точность (доля правильно классифицированных изображений).

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Теперь можно начинать обучение сети, для чего в случае использования библиотеки Keras
# достаточно вызвать метод fit сети — он пытается адаптировать (fit) модель под обучающие
# данные.

# %%
f = model.fit(X, dummy_y, epochs=170, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/170
# 14/14 [==============================] - 2s 49ms/step - loss: 1.4369 - accuracy: 0.4222 - val_loss: 3.1974 - val_accuracy: 0.0000e+00
# Epoch 2/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.3657 - accuracy: 0.4148 - val_loss: 2.7857 - val_accuracy: 0.0000e+00
# Epoch 3/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2977 - accuracy: 0.3926 - val_loss: 2.4706 - val_accuracy: 0.0000e+00
# Epoch 4/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.2501 - accuracy: 0.3926 - val_loss: 2.2278 - val_accuracy: 0.0000e+00
# Epoch 5/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2107 - accuracy: 0.4000 - val_loss: 2.0672 - val_accuracy: 0.0000e+00
# Epoch 6/170
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1866 - accuracy: 0.4444 - val_loss: 1.9135 - val_accuracy: 0.0000e+00
# Epoch 7/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1631 - accuracy: 0.5111 - val_loss: 1.8250 - val_accuracy: 0.0000e+00
# Epoch 8/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1475 - accuracy: 0.5407 - val_loss: 1.7118 - val_accuracy: 0.0000e+00
# Epoch 9/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1349 - accuracy: 0.5259 - val_loss: 1.5947 - val_accuracy: 0.0000e+00
# Epoch 10/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1286 - accuracy: 0.4963 - val_loss: 1.5618 - val_accuracy: 0.0000e+00
# Epoch 11/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1166 - accuracy: 0.4815 - val_loss: 1.4968 - val_accuracy: 0.0000e+00
# Epoch 12/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1108 - accuracy: 0.4370 - val_loss: 1.4637 - val_accuracy: 0.0000e+00
# Epoch 13/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1059 - accuracy: 0.4148 - val_loss: 1.4219 - val_accuracy: 0.0000e+00
# Epoch 14/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1006 - accuracy: 0.4222 - val_loss: 1.3829 - val_accuracy: 0.0000e+00
# Epoch 15/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0963 - accuracy: 0.3778 - val_loss: 1.3809 - val_accuracy: 0.0000e+00
# Epoch 16/170
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0925 - accuracy: 0.3481 - val_loss: 1.3593 - val_accuracy: 0.0000e+00
# Epoch 17/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0920 - accuracy: 0.3185 - val_loss: 1.3029 - val_accuracy: 0.0000e+00
# Epoch 18/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0862 - accuracy: 0.3185 - val_loss: 1.2960 - val_accuracy: 0.0667
# Epoch 19/170
# 14/14 [==============================] - 0s 13ms/step - loss: 1.0833 - accuracy: 0.3333 - val_loss: 1.3102 - val_accuracy: 0.1333
# Epoch 20/170
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0811 - accuracy: 0.3407 - val_loss: 1.3156 - val_accuracy: 0.2000
# Epoch 21/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0792 - accuracy: 0.3407 - val_loss: 1.3061 - val_accuracy: 0.2000
# Epoch 22/170
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0768 - accuracy: 0.3481 - val_loss: 1.2696 - val_accuracy: 0.2667
# Epoch 23/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0755 - accuracy: 0.3556 - val_loss: 1.2097 - val_accuracy: 0.2667
# Epoch 24/170
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0726 - accuracy: 0.3481 - val_loss: 1.2206 - val_accuracy: 0.2667
# Epoch 25/170
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0701 - accuracy: 0.3556 - val_loss: 1.2517 - val_accuracy: 0.2667
# Epoch 26/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0708 - accuracy: 0.3556 - val_loss: 1.2842 - val_accuracy: 0.2000
# Epoch 27/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0670 - accuracy: 0.3556 - val_loss: 1.2275 - val_accuracy: 0.2667
# Epoch 28/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0663 - accuracy: 0.3556 - val_loss: 1.2044 - val_accuracy: 0.2667
# Epoch 29/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0641 - accuracy: 0.3481 - val_loss: 1.2165 - val_accuracy: 0.2667
# Epoch 30/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0625 - accuracy: 0.3556 - val_loss: 1.1967 - val_accuracy: 0.2667
# Epoch 31/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0598 - accuracy: 0.3630 - val_loss: 1.2090 - val_accuracy: 0.2667
# Epoch 32/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0606 - accuracy: 0.3407 - val_loss: 1.1676 - val_accuracy: 0.2667
# Epoch 33/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0580 - accuracy: 0.3556 - val_loss: 1.2061 - val_accuracy: 0.2667
# Epoch 34/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0556 - accuracy: 0.3630 - val_loss: 1.1496 - val_accuracy: 0.3333
# Epoch 35/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0528 - accuracy: 0.3556 - val_loss: 1.1734 - val_accuracy: 0.2667
# Epoch 36/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0517 - accuracy: 0.3556 - val_loss: 1.1909 - val_accuracy: 0.2667
# Epoch 37/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0486 - accuracy: 0.3556 - val_loss: 1.1418 - val_accuracy: 0.3333
# Epoch 38/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0492 - accuracy: 0.3704 - val_loss: 1.1095 - val_accuracy: 0.5333
# Epoch 39/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0458 - accuracy: 0.3481 - val_loss: 1.1551 - val_accuracy: 0.2667
# Epoch 40/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0430 - accuracy: 0.3481 - val_loss: 1.1687 - val_accuracy: 0.2667
# Epoch 41/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0423 - accuracy: 0.3481 - val_loss: 1.1410 - val_accuracy: 0.3333
# Epoch 42/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0393 - accuracy: 0.3481 - val_loss: 1.1318 - val_accuracy: 0.3333
# Epoch 43/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0366 - accuracy: 0.3556 - val_loss: 1.1619 - val_accuracy: 0.2667
# Epoch 44/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0345 - accuracy: 0.3556 - val_loss: 1.1523 - val_accuracy: 0.2667
# Epoch 45/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0316 - accuracy: 0.3630 - val_loss: 1.1785 - val_accuracy: 0.2667
# Epoch 46/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0296 - accuracy: 0.3630 - val_loss: 1.1614 - val_accuracy: 0.2667
# Epoch 47/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0288 - accuracy: 0.3407 - val_loss: 1.1844 - val_accuracy: 0.2000
# Epoch 48/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0243 - accuracy: 0.3630 - val_loss: 1.1347 - val_accuracy: 0.2667
# Epoch 49/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0224 - accuracy: 0.3556 - val_loss: 1.1358 - val_accuracy: 0.2667
# Epoch 50/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0198 - accuracy: 0.3407 - val_loss: 1.1364 - val_accuracy: 0.2667
# Epoch 51/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0166 - accuracy: 0.3481 - val_loss: 1.1097 - val_accuracy: 0.3333
# Epoch 52/170
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0137 - accuracy: 0.3481 - val_loss: 1.1181 - val_accuracy: 0.2667
# Epoch 53/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0149 - accuracy: 0.3704 - val_loss: 1.1447 - val_accuracy: 0.2667
# Epoch 54/170
# 14/14 [==============================] - 0s 9ms/step - loss: 1.0082 - accuracy: 0.3704 - val_loss: 1.1013 - val_accuracy: 0.4000
# Epoch 55/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0070 - accuracy: 0.3778 - val_loss: 1.1242 - val_accuracy: 0.2667
# Epoch 56/170
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0012 - accuracy: 0.3852 - val_loss: 1.0960 - val_accuracy: 0.3333
# Epoch 57/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9986 - accuracy: 0.4148 - val_loss: 1.1159 - val_accuracy: 0.2667
# Epoch 58/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9948 - accuracy: 0.4444 - val_loss: 1.0754 - val_accuracy: 0.4000
# Epoch 59/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9909 - accuracy: 0.4519 - val_loss: 1.0623 - val_accuracy: 0.4000
# Epoch 60/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9910 - accuracy: 0.5037 - val_loss: 1.1119 - val_accuracy: 0.2667
# Epoch 61/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9827 - accuracy: 0.4741 - val_loss: 1.0807 - val_accuracy: 0.3333
# Epoch 62/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9791 - accuracy: 0.5037 - val_loss: 1.0599 - val_accuracy: 0.4000
# Epoch 63/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9748 - accuracy: 0.5333 - val_loss: 1.0832 - val_accuracy: 0.2667
# Epoch 64/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9710 - accuracy: 0.5778 - val_loss: 1.0739 - val_accuracy: 0.2667
# Epoch 65/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9674 - accuracy: 0.6074 - val_loss: 1.0787 - val_accuracy: 0.2667
# Epoch 66/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9625 - accuracy: 0.6148 - val_loss: 1.0579 - val_accuracy: 0.3333
# Epoch 67/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9581 - accuracy: 0.6370 - val_loss: 1.0791 - val_accuracy: 0.2667
# Epoch 68/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9527 - accuracy: 0.6370 - val_loss: 1.0406 - val_accuracy: 0.4000
# Epoch 69/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9472 - accuracy: 0.6370 - val_loss: 1.0703 - val_accuracy: 0.2667
# Epoch 70/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9429 - accuracy: 0.6444 - val_loss: 1.0279 - val_accuracy: 0.4000
# Epoch 71/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9381 - accuracy: 0.6444 - val_loss: 1.0624 - val_accuracy: 0.2667
# Epoch 72/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9327 - accuracy: 0.6963 - val_loss: 1.0353 - val_accuracy: 0.3333
# Epoch 73/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9263 - accuracy: 0.6815 - val_loss: 1.0723 - val_accuracy: 0.2000
# Epoch 74/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9234 - accuracy: 0.6667 - val_loss: 1.0919 - val_accuracy: 0.2000
# Epoch 75/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9146 - accuracy: 0.6741 - val_loss: 1.0547 - val_accuracy: 0.2667
# Epoch 76/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9073 - accuracy: 0.6963 - val_loss: 1.0165 - val_accuracy: 0.3333
# Epoch 77/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9053 - accuracy: 0.7037 - val_loss: 0.9769 - val_accuracy: 0.4667
# Epoch 78/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8964 - accuracy: 0.7259 - val_loss: 0.9941 - val_accuracy: 0.4000
# Epoch 79/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8912 - accuracy: 0.7185 - val_loss: 1.0217 - val_accuracy: 0.2667
# Epoch 80/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8844 - accuracy: 0.7185 - val_loss: 1.0129 - val_accuracy: 0.2667
# Epoch 81/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.8777 - accuracy: 0.7111 - val_loss: 0.9762 - val_accuracy: 0.4000
# Epoch 82/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8710 - accuracy: 0.7185 - val_loss: 0.9646 - val_accuracy: 0.4000
# Epoch 83/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8644 - accuracy: 0.7185 - val_loss: 0.9701 - val_accuracy: 0.3333
# Epoch 84/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8614 - accuracy: 0.6963 - val_loss: 1.0200 - val_accuracy: 0.2000
# Epoch 85/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8517 - accuracy: 0.7037 - val_loss: 0.9623 - val_accuracy: 0.3333
# Epoch 86/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.8447 - accuracy: 0.7185 - val_loss: 0.9380 - val_accuracy: 0.4000
# Epoch 87/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.8395 - accuracy: 0.7037 - val_loss: 0.9356 - val_accuracy: 0.4000
# Epoch 88/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8330 - accuracy: 0.7111 - val_loss: 0.9073 - val_accuracy: 0.4667
# Epoch 89/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.8263 - accuracy: 0.7185 - val_loss: 0.9053 - val_accuracy: 0.4000
# Epoch 90/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8197 - accuracy: 0.7185 - val_loss: 0.9111 - val_accuracy: 0.4000
# Epoch 91/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8135 - accuracy: 0.7185 - val_loss: 0.9171 - val_accuracy: 0.4000
# Epoch 92/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8089 - accuracy: 0.7037 - val_loss: 0.8943 - val_accuracy: 0.4000
# Epoch 93/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8006 - accuracy: 0.7111 - val_loss: 0.9474 - val_accuracy: 0.2000
# Epoch 94/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7969 - accuracy: 0.7037 - val_loss: 0.9047 - val_accuracy: 0.4000
# Epoch 95/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7883 - accuracy: 0.7185 - val_loss: 0.9121 - val_accuracy: 0.2667
# Epoch 96/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7823 - accuracy: 0.7185 - val_loss: 0.9067 - val_accuracy: 0.2667
# Epoch 97/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7765 - accuracy: 0.7259 - val_loss: 0.8877 - val_accuracy: 0.4000
# Epoch 98/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7706 - accuracy: 0.7185 - val_loss: 0.8909 - val_accuracy: 0.4000
# Epoch 99/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7647 - accuracy: 0.7259 - val_loss: 0.9086 - val_accuracy: 0.2667
# Epoch 100/170
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7599 - accuracy: 0.7185 - val_loss: 0.9119 - val_accuracy: 0.2000
# Epoch 101/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7544 - accuracy: 0.7259 - val_loss: 0.8752 - val_accuracy: 0.4000
# Epoch 102/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7487 - accuracy: 0.7185 - val_loss: 0.8690 - val_accuracy: 0.4000
# Epoch 103/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7429 - accuracy: 0.7259 - val_loss: 0.8726 - val_accuracy: 0.2667
# Epoch 104/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7369 - accuracy: 0.7259 - val_loss: 0.8499 - val_accuracy: 0.4000
# Epoch 105/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7328 - accuracy: 0.7185 - val_loss: 0.8083 - val_accuracy: 0.4667
# Epoch 106/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7265 - accuracy: 0.7259 - val_loss: 0.8460 - val_accuracy: 0.4000
# Epoch 107/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7213 - accuracy: 0.7259 - val_loss: 0.8455 - val_accuracy: 0.4000
# Epoch 108/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7164 - accuracy: 0.7111 - val_loss: 0.8200 - val_accuracy: 0.4000
# Epoch 109/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7110 - accuracy: 0.7111 - val_loss: 0.8126 - val_accuracy: 0.4667
# Epoch 110/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7063 - accuracy: 0.7111 - val_loss: 0.7963 - val_accuracy: 0.4667
# Epoch 111/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7013 - accuracy: 0.7111 - val_loss: 0.8028 - val_accuracy: 0.4667
# Epoch 112/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6971 - accuracy: 0.7111 - val_loss: 0.7984 - val_accuracy: 0.4667
# Epoch 113/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6921 - accuracy: 0.7185 - val_loss: 0.8041 - val_accuracy: 0.4000
# Epoch 114/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6868 - accuracy: 0.7185 - val_loss: 0.7724 - val_accuracy: 0.4667
# Epoch 115/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6826 - accuracy: 0.7333 - val_loss: 0.7558 - val_accuracy: 0.4667
# Epoch 116/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6786 - accuracy: 0.7333 - val_loss: 0.7532 - val_accuracy: 0.4667
# Epoch 117/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6776 - accuracy: 0.7259 - val_loss: 0.8132 - val_accuracy: 0.3333
# Epoch 118/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6697 - accuracy: 0.7333 - val_loss: 0.7844 - val_accuracy: 0.4667
# Epoch 119/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6656 - accuracy: 0.7259 - val_loss: 0.7861 - val_accuracy: 0.4667
# Epoch 120/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6621 - accuracy: 0.7185 - val_loss: 0.7733 - val_accuracy: 0.4667
# Epoch 121/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6574 - accuracy: 0.7185 - val_loss: 0.8060 - val_accuracy: 0.3333
# Epoch 122/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6533 - accuracy: 0.7333 - val_loss: 0.7910 - val_accuracy: 0.4000
# Epoch 123/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6496 - accuracy: 0.7407 - val_loss: 0.7483 - val_accuracy: 0.4667
# Epoch 124/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6460 - accuracy: 0.7333 - val_loss: 0.7390 - val_accuracy: 0.5333
# Epoch 125/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6409 - accuracy: 0.7333 - val_loss: 0.7736 - val_accuracy: 0.4667
# Epoch 126/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6371 - accuracy: 0.7556 - val_loss: 0.7778 - val_accuracy: 0.4667
# Epoch 127/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6348 - accuracy: 0.7407 - val_loss: 0.7861 - val_accuracy: 0.3333
# Epoch 128/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6292 - accuracy: 0.7556 - val_loss: 0.7536 - val_accuracy: 0.4667
# Epoch 129/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6258 - accuracy: 0.7333 - val_loss: 0.7149 - val_accuracy: 0.5333
# Epoch 130/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6235 - accuracy: 0.7333 - val_loss: 0.7050 - val_accuracy: 0.6000
# Epoch 131/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6193 - accuracy: 0.7481 - val_loss: 0.7047 - val_accuracy: 0.6000
# Epoch 132/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6180 - accuracy: 0.7333 - val_loss: 0.7523 - val_accuracy: 0.4667
# Epoch 133/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6126 - accuracy: 0.7481 - val_loss: 0.7049 - val_accuracy: 0.5333
# Epoch 134/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6090 - accuracy: 0.7407 - val_loss: 0.7177 - val_accuracy: 0.5333
# Epoch 135/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6071 - accuracy: 0.7481 - val_loss: 0.7329 - val_accuracy: 0.4667
# Epoch 136/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6030 - accuracy: 0.7481 - val_loss: 0.7080 - val_accuracy: 0.5333
# Epoch 137/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5998 - accuracy: 0.7407 - val_loss: 0.6945 - val_accuracy: 0.6667
# Epoch 138/170
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5966 - accuracy: 0.7556 - val_loss: 0.7048 - val_accuracy: 0.5333
# Epoch 139/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5938 - accuracy: 0.7481 - val_loss: 0.7098 - val_accuracy: 0.5333
# Epoch 140/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5904 - accuracy: 0.7556 - val_loss: 0.7069 - val_accuracy: 0.5333
# Epoch 141/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5878 - accuracy: 0.7556 - val_loss: 0.7180 - val_accuracy: 0.5333
# Epoch 142/170
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5852 - accuracy: 0.7556 - val_loss: 0.7195 - val_accuracy: 0.5333
# Epoch 143/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5836 - accuracy: 0.7407 - val_loss: 0.6714 - val_accuracy: 0.7333
# Epoch 144/170
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5815 - accuracy: 0.7407 - val_loss: 0.7028 - val_accuracy: 0.5333
# Epoch 145/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5761 - accuracy: 0.7630 - val_loss: 0.6888 - val_accuracy: 0.5333
# Epoch 146/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5737 - accuracy: 0.7556 - val_loss: 0.7164 - val_accuracy: 0.5333
# Epoch 147/170
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5704 - accuracy: 0.7630 - val_loss: 0.6989 - val_accuracy: 0.5333
# Epoch 148/170
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5690 - accuracy: 0.7481 - val_loss: 0.6629 - val_accuracy: 0.8667
# Epoch 149/170
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5659 - accuracy: 0.7481 - val_loss: 0.6683 - val_accuracy: 0.7333
# Epoch 150/170
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5633 - accuracy: 0.7556 - val_loss: 0.6842 - val_accuracy: 0.6000
# Epoch 151/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5606 - accuracy: 0.7704 - val_loss: 0.6865 - val_accuracy: 0.5333
# Epoch 152/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5588 - accuracy: 0.7630 - val_loss: 0.6985 - val_accuracy: 0.5333
# Epoch 153/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5563 - accuracy: 0.7481 - val_loss: 0.6717 - val_accuracy: 0.6667
# Epoch 154/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5533 - accuracy: 0.7704 - val_loss: 0.6732 - val_accuracy: 0.6667
# Epoch 155/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5507 - accuracy: 0.7704 - val_loss: 0.6786 - val_accuracy: 0.6000
# Epoch 156/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5492 - accuracy: 0.7556 - val_loss: 0.7075 - val_accuracy: 0.5333
# Epoch 157/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5463 - accuracy: 0.7630 - val_loss: 0.6958 - val_accuracy: 0.5333
# Epoch 158/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5440 - accuracy: 0.7630 - val_loss: 0.6949 - val_accuracy: 0.5333
# Epoch 159/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5429 - accuracy: 0.7630 - val_loss: 0.6662 - val_accuracy: 0.8000
# Epoch 160/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5403 - accuracy: 0.7778 - val_loss: 0.6776 - val_accuracy: 0.6000
# Epoch 161/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5375 - accuracy: 0.7778 - val_loss: 0.6785 - val_accuracy: 0.6000
# Epoch 162/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5357 - accuracy: 0.7778 - val_loss: 0.6783 - val_accuracy: 0.6000
# Epoch 163/170
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5342 - accuracy: 0.7778 - val_loss: 0.6972 - val_accuracy: 0.5333
# Epoch 164/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5313 - accuracy: 0.7556 - val_loss: 0.6656 - val_accuracy: 0.8000
# Epoch 165/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5294 - accuracy: 0.7704 - val_loss: 0.6655 - val_accuracy: 0.8000
# Epoch 166/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5273 - accuracy: 0.7852 - val_loss: 0.6492 - val_accuracy: 0.8667
# Epoch 167/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5252 - accuracy: 0.7926 - val_loss: 0.6683 - val_accuracy: 0.8000
# Epoch 168/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5235 - accuracy: 0.7778 - val_loss: 0.6575 - val_accuracy: 0.8000
# Epoch 169/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5212 - accuracy: 0.7778 - val_loss: 0.6653 - val_accuracy: 0.8000
# Epoch 170/170
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5197 - accuracy: 0.7778 - val_loss: 0.6913 - val_accuracy: 0.5333

# %% [markdown]
# В процессе обучения отображаются четыре величины: потери сети на обучающих данных
# и точность сети на обучающих данных, а также потери и точность на данных, не
# участвовавших в обучении.

# %% [markdown]
# ### Начертим график, который наглядно покажет точность обучающих данных и тестируемых данных.

# %%
fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax.plot(f.history['accuracy'],color=('green'),marker='o',linewidth=1.5,label='точность обучающих данных')
ax.plot(f.history['val_accuracy'],color=('gray'),marker='o',linewidth=1.5,label='точность тестируемых данных')
## ax.plot(f.history['loss'],color=('red'),marker='o',linewidth=1.5,label='потери')
ax.set_title('График точности',fontsize=35)
ax.set_xlabel("Количество эпох",fontsize=30)
ax.set_ylabel("Точность",fontsize=30)
ax.legend(loc='best',fontsize=30)

# %%
fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax.plot(f.history['loss'],color=('green'),marker='o',linewidth=1.5,label='потери обучающих данных')
ax.plot(f.history['val_loss'],color=('gray'),marker='o',linewidth=1.5,label='потери тестируемых данных')
## ax.plot(f.history['loss'],color=('red'),marker='o',linewidth=1.5,label='потери')
ax.set_title('График потерь',fontsize=35)
ax.set_xlabel("Количество эпох",fontsize=30)
ax.set_ylabel("Потери",fontsize=30)
ax.legend(loc='best',fontsize=30)

# %% [markdown]
# ## Вопрос 1
# ### Поменяем архитектуру нейронной сети, а именно поменяем количество слоёв. Добавим еще один слой в нашу нейросеть. Параметры обучения оставим такими же как и были.

# %%
model1 = Sequential()
model1.add(Dense(4, activation='relu'))
model1.add(Dense(8, activation='tanh'))
model1.add(Dense(3, activation='softmax'))

model1.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

f1 = model1.fit(X, dummy_y, epochs=70, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/70
# 14/14 [==============================] - 2s 57ms/step - loss: 0.9728 - accuracy: 0.4296 - val_loss: 0.8224 - val_accuracy: 0.6667
# Epoch 2/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.9522 - accuracy: 0.4444 - val_loss: 0.7843 - val_accuracy: 0.8000
# Epoch 3/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.9303 - accuracy: 0.5111 - val_loss: 0.8041 - val_accuracy: 0.6667
# Epoch 4/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.9102 - accuracy: 0.5778 - val_loss: 0.8090 - val_accuracy: 0.6667
# Epoch 5/70
# 14/14 [==============================] - 0s 14ms/step - loss: 0.8873 - accuracy: 0.7037 - val_loss: 0.7609 - val_accuracy: 0.7333
# Epoch 6/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.8648 - accuracy: 0.7704 - val_loss: 0.7322 - val_accuracy: 0.8000
# Epoch 7/70
# 14/14 [==============================] - 0s 14ms/step - loss: 0.8408 - accuracy: 0.8000 - val_loss: 0.7223 - val_accuracy: 0.8000
# Epoch 8/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.8174 - accuracy: 0.8148 - val_loss: 0.7042 - val_accuracy: 0.8000
# Epoch 9/70
# 14/14 [==============================] - 0s 16ms/step - loss: 0.7954 - accuracy: 0.7852 - val_loss: 0.6740 - val_accuracy: 0.8000
# Epoch 10/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7728 - accuracy: 0.8074 - val_loss: 0.6973 - val_accuracy: 0.6667
# Epoch 11/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7515 - accuracy: 0.7852 - val_loss: 0.6770 - val_accuracy: 0.8000
# Epoch 12/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7308 - accuracy: 0.8074 - val_loss: 0.6621 - val_accuracy: 0.8000
# Epoch 13/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7103 - accuracy: 0.8000 - val_loss: 0.6854 - val_accuracy: 0.6667
# Epoch 14/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6918 - accuracy: 0.8000 - val_loss: 0.6678 - val_accuracy: 0.6667
# Epoch 15/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6731 - accuracy: 0.8148 - val_loss: 0.6502 - val_accuracy: 0.7333
# Epoch 16/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6550 - accuracy: 0.7926 - val_loss: 0.6577 - val_accuracy: 0.6667
# Epoch 17/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6391 - accuracy: 0.8000 - val_loss: 0.6411 - val_accuracy: 0.6667
# Epoch 18/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6225 - accuracy: 0.8148 - val_loss: 0.6770 - val_accuracy: 0.6667
# Epoch 19/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6081 - accuracy: 0.8296 - val_loss: 0.6209 - val_accuracy: 0.8000
# Epoch 20/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5898 - accuracy: 0.8000 - val_loss: 0.6314 - val_accuracy: 0.6667
# Epoch 21/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5750 - accuracy: 0.8296 - val_loss: 0.6597 - val_accuracy: 0.6667
# Epoch 22/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5614 - accuracy: 0.8222 - val_loss: 0.6481 - val_accuracy: 0.6667
# Epoch 23/70
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5479 - accuracy: 0.8222 - val_loss: 0.6399 - val_accuracy: 0.6667
# Epoch 24/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5353 - accuracy: 0.8148 - val_loss: 0.6134 - val_accuracy: 0.6667
# Epoch 25/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5229 - accuracy: 0.8370 - val_loss: 0.6265 - val_accuracy: 0.6667
# Epoch 26/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5115 - accuracy: 0.8296 - val_loss: 0.6009 - val_accuracy: 0.6667
# Epoch 27/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4999 - accuracy: 0.8370 - val_loss: 0.6062 - val_accuracy: 0.6667
# Epoch 28/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4897 - accuracy: 0.8444 - val_loss: 0.6293 - val_accuracy: 0.6667
# Epoch 29/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4801 - accuracy: 0.8370 - val_loss: 0.5783 - val_accuracy: 0.8000
# Epoch 30/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4703 - accuracy: 0.8593 - val_loss: 0.5725 - val_accuracy: 0.8000
# Epoch 31/70
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4614 - accuracy: 0.8444 - val_loss: 0.6015 - val_accuracy: 0.6667
# Epoch 32/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4525 - accuracy: 0.8593 - val_loss: 0.5987 - val_accuracy: 0.6667
# Epoch 33/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4452 - accuracy: 0.8667 - val_loss: 0.5952 - val_accuracy: 0.6667
# Epoch 34/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4360 - accuracy: 0.8593 - val_loss: 0.5325 - val_accuracy: 0.8000
# Epoch 35/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4299 - accuracy: 0.8667 - val_loss: 0.5509 - val_accuracy: 0.8000
# Epoch 36/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4225 - accuracy: 0.8815 - val_loss: 0.5873 - val_accuracy: 0.6667
# Epoch 37/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4153 - accuracy: 0.8667 - val_loss: 0.5561 - val_accuracy: 0.8000
# Epoch 38/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4090 - accuracy: 0.8667 - val_loss: 0.5510 - val_accuracy: 0.8000
# Epoch 39/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4022 - accuracy: 0.8667 - val_loss: 0.5492 - val_accuracy: 0.8000
# Epoch 40/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3970 - accuracy: 0.8667 - val_loss: 0.5184 - val_accuracy: 0.8000
# Epoch 41/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3902 - accuracy: 0.8889 - val_loss: 0.5459 - val_accuracy: 0.8000
# Epoch 42/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3849 - accuracy: 0.8741 - val_loss: 0.5481 - val_accuracy: 0.8000
# Epoch 43/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3802 - accuracy: 0.8889 - val_loss: 0.5308 - val_accuracy: 0.8000
# Epoch 44/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3742 - accuracy: 0.8889 - val_loss: 0.5222 - val_accuracy: 0.8000
# Epoch 45/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3688 - accuracy: 0.8889 - val_loss: 0.5161 - val_accuracy: 0.8000
# Epoch 46/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3644 - accuracy: 0.8963 - val_loss: 0.4951 - val_accuracy: 0.8000
# Epoch 47/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3611 - accuracy: 0.8889 - val_loss: 0.5336 - val_accuracy: 0.8000
# Epoch 48/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3547 - accuracy: 0.8963 - val_loss: 0.4907 - val_accuracy: 0.8000
# Epoch 49/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3507 - accuracy: 0.9037 - val_loss: 0.5021 - val_accuracy: 0.8000
# Epoch 50/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3478 - accuracy: 0.8963 - val_loss: 0.4684 - val_accuracy: 0.8000
# Epoch 51/70
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3407 - accuracy: 0.8963 - val_loss: 0.4975 - val_accuracy: 0.8000
# Epoch 52/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3377 - accuracy: 0.9037 - val_loss: 0.5311 - val_accuracy: 0.8000
# Epoch 53/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3326 - accuracy: 0.9037 - val_loss: 0.4881 - val_accuracy: 0.8000
# Epoch 54/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3280 - accuracy: 0.9037 - val_loss: 0.4436 - val_accuracy: 0.8000
# Epoch 55/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3253 - accuracy: 0.9111 - val_loss: 0.4376 - val_accuracy: 0.8000
# Epoch 56/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3210 - accuracy: 0.9111 - val_loss: 0.4693 - val_accuracy: 0.8000
# Epoch 57/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3192 - accuracy: 0.9037 - val_loss: 0.4595 - val_accuracy: 0.8000
# Epoch 58/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3140 - accuracy: 0.9111 - val_loss: 0.4513 - val_accuracy: 0.8000
# Epoch 59/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3109 - accuracy: 0.9185 - val_loss: 0.4128 - val_accuracy: 0.8000
# Epoch 60/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3066 - accuracy: 0.9111 - val_loss: 0.4620 - val_accuracy: 0.8000
# Epoch 61/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3030 - accuracy: 0.9111 - val_loss: 0.4497 - val_accuracy: 0.8000
# Epoch 62/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2991 - accuracy: 0.9111 - val_loss: 0.4493 - val_accuracy: 0.8000
# Epoch 63/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2978 - accuracy: 0.9185 - val_loss: 0.3915 - val_accuracy: 0.8667
# Epoch 64/70
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2921 - accuracy: 0.9037 - val_loss: 0.4231 - val_accuracy: 0.8000
# Epoch 65/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2936 - accuracy: 0.9111 - val_loss: 0.4587 - val_accuracy: 0.8000
# Epoch 66/70
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2850 - accuracy: 0.9111 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 67/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2822 - accuracy: 0.9111 - val_loss: 0.4176 - val_accuracy: 0.8000
# Epoch 68/70
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2793 - accuracy: 0.9185 - val_loss: 0.3991 - val_accuracy: 0.8667
# Epoch 69/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2753 - accuracy: 0.9111 - val_loss: 0.4299 - val_accuracy: 0.8000
# Epoch 70/70
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2735 - accuracy: 0.9185 - val_loss: 0.3873 - val_accuracy: 0.8667

# %%
fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax.plot(f1.history['accuracy'],color=('green'),marker='o',linewidth=1.5,label='точность обучающих данных')
ax.plot(f1.history['val_accuracy'],color=('gray'),marker='o',linewidth=1.5,label='точность тестируемых данных')
ax.set_title('График точности',fontsize=35)
ax.set_xlabel("Количество эпох",fontsize=30)
ax.set_ylabel("Точность",fontsize=30)
ax.legend(loc='best',fontsize=30)

# %%
fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax.plot(f1.history['loss'],color=('green'),marker='o',linewidth=1.5,label='потери обучающих данных')
ax.plot(f1.history['val_loss'],color=('gray'),marker='o',linewidth=1.5,label='потери тестируемых данных')
ax.set_title('График потерь',fontsize=35)
ax.set_xlabel("Количество эпох",fontsize=30)
ax.set_ylabel("Потери",fontsize=30)
ax.legend(loc='best',fontsize=30)

# %% [markdown]
# ### Вопрос 2
# ### Поменяем параметры обучения (function fit) в моделях которые были ранее представлены.

# %%
## зададим параметры обучения для 1 сети
f3 = model.fit(X, dummy_y, epochs=175,batch_size=20, validation_split=0.1,verbose=0)

# %%
figure = plt.figure(figsize=(25, 25))
ax1 = figure.add_subplot(1,2,1)
ax2 = figure.add_subplot(1,2,2)
##fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax1.plot(f3.history['accuracy'],color=('green'),marker='o',linewidth=1.5,label='точность обучающих данных')
ax1.plot(f3.history['val_accuracy'],color=('gray'),marker='o',linewidth=1.5,label='точность тестируемых данных')
## ax.plot(f.history['loss'],color=('red'),marker='o',linewidth=1.5,label='потери')
ax1.set_title('График точности',fontsize=35)
ax1.set_xlabel("Количество эпох",fontsize=30)
ax1.set_ylabel("Точность",fontsize=30)
ax1.legend(loc='best',fontsize=30)

plt.rcParams.update({'font.size': 30})
ax2.plot(f3.history['loss'],color=('green'),marker='o',linewidth=1.5,label='потери обучающих данных')
ax2.plot(f3.history['val_loss'],color=('gray'),marker='o',linewidth=1.5,label='потери тестируемых данных')
ax2.set_title('График потерь',fontsize=35)
ax2.set_xlabel("Количество эпох",fontsize=30)
ax2.set_ylabel("Потери",fontsize=30)
ax2.legend(loc='best',fontsize=30)

# %%
## зададим параметры обучения для 2 сети
f4 = model1.fit(X, dummy_y,batch_size=20,epochs=70, validation_split=0.1,verbose=0)

figure = plt.figure(figsize=(25, 25))
ax1 = figure.add_subplot(1,2,1)
ax2 = figure.add_subplot(1,2,2)
##fig, ax = plt.subplots(figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
ax1.plot(f4.history['accuracy'],color=('green'),marker='o',linewidth=1.5,label='точность обучающих данных')
ax1.plot(f4.history['val_accuracy'],color=('gray'),marker='o',linewidth=1.5,label='точность тестируемых данных')
## ax.plot(f.history['loss'],color=('red'),marker='o',linewidth=1.5,label='потери')
ax1.set_title('График точности',fontsize=35)
ax1.set_xlabel("Количество эпох",fontsize=30)
ax1.set_ylabel("Точность",fontsize=30)
ax1.legend(loc='best',fontsize=30)

plt.rcParams.update({'font.size': 30})
ax2.plot(f4.history['loss'],color=('green'),marker='o',linewidth=1.5,label='потери обучающих данных')
ax2.plot(f4.history['val_loss'],color=('gray'),marker='o',linewidth=1.5,label='потери тестируемых данных')
ax2.set_title('График потерь',fontsize=35)
ax2.set_xlabel("Количество эпох",fontsize=30)
ax2.set_ylabel("Потери",fontsize=30)
ax2.legend(loc='best',fontsize=30)

# %%
fig, axes = plt.subplots(2,2,figsize=(25, 15))
plt.rcParams.update({'font.size': 30})
axes[0,0].plot(f.history['accuracy'],color=('green'),linewidth=1.5,label='1 модель')
axes[0,0].plot(f1.history['accuracy'],color=('red'),linewidth=1.5,label='2 модель')
axes[0,0].plot(f3.history['accuracy'],color=('blue'),linewidth=1.5,label='3 модель')
axes[0,0].plot(f4.history['accuracy'],color=('gray'),linewidth=1.5,label='4 модель')
axes[0,0].set_title('График точности при обучающих данных',fontsize=35)
axes[0,0].legend(loc='best')

axes[0,1].plot(f.history['val_accuracy'],color=('green'),linewidth=1.5,label='1 модель')
axes[0,1].plot(f1.history['val_accuracy'],color=('red'),linewidth=1.5,label='2 модель')
axes[0,1].plot(f3.history['val_accuracy'],color=('blue'),linewidth=1.5,label='3 модель')
axes[0,1].plot(f4.history['val_accuracy'],color=('gray'),linewidth=1.5,label='4 модель')
axes[0,1].legend(loc='best')
axes[0,1].set_title('График точности при тестируемых данных',fontsize=35)

axes[1,0].plot(f.history['loss'],color=('green'),linewidth=1.5,label='1 модель')
axes[1,0].plot(f1.history['loss'],color=('red'),linewidth=1.5,label='2 модель')
axes[1,0].plot(f3.history['loss'],color=('blue'),linewidth=1.5,label='3 модель')
axes[1,0].plot(f4.history['loss'],color=('gray'),linewidth=1.5,label='4 модель')
axes[1,0].set_title('График потерь при обучающих данных',fontsize=35)
axes[1,0].legend(loc='best')

axes[1,1].plot(f.history['val_loss'],color=('green'),linewidth=1.5,label='1 модель')
axes[1,1].plot(f1.history['val_loss'],color=('red'),linewidth=1.5,label='2 модель')
axes[1,1].plot(f3.history['val_loss'],color=('blue'),linewidth=1.5,label='3 модель')
axes[1,1].plot(f4.history['val_loss'],color=('gray'),linewidth=1.5,label='4 модель')
axes[1,1].set_title('График потерь при тестируемых данных',fontsize=35)
axes[1,1].legend(loc='best')

# %% [markdown]
# ## Вывод
# 3 модель показывает себя лучше всех других.
